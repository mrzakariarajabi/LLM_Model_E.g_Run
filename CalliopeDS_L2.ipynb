# %%
# !pip install ctransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 24.2 MB/s eta 0:00:00
# ...

# %%
from ctransformers import AutoModelForCausalLM

# %%
# !wget https://huggingface.co/TheBloke/CalliopeDS-L2-13B-GGUF/resolve/main/calliopeds-l2-13b.Q4_0.gguf
# Out:
# --2024-04-09 05:51:58--  https://huggingface.co/TheBloke/CalliopeDS-L2-13B-GGUF/resolve/main/calliopeds-l2-13b.Q4_0.gguf
# Resolving huggingface.co (huggingface.co)... 18.164.174.118, 18.164.174.17, 18.164.174.23, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.118|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !ls
# Out:
# calliopeds-l2-13b.Q4_0.gguf  sample_data

# %%
local_llm = "calliopeds-l2-13b.Q4_0.gguf"

# %%
# Set gpu_layers to the number of layers to offload to GPU. Set to 0 if no GPU acceleration is available on your system.
llm = AutoModelForCausalLM.from_pretrained("TheBloke/CalliopeDS-L2-13B-GGUF", model_file=local_llm, model_type="llama", gpu_layers=500)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# calliopeds-l2-13b.Q4_0.gguf:   0%|          | 0.00/7.37G [00:00<?, ?B/s]

# %%
print(llm("what is sign of stomach ache"))
# Out:
# ?
# Is there a sign of stomach ache or can it just be an aching feeling in the abdomen?
# Stomach ache, also known as abdominal pain, can have various causes and signs associated with it. In some cases, there might not be any visible sign of a stomach ache. It could just be an aching feeling in the abdomen. However, other common signs of stomach ache include:
# - Pain or discomfort in the upper abdomen, below the ribs and above the navel
# - Bloating or a feeling of fullness in the abdomen
# - Nausea or vomiting
# - Burping or belching
# - Heartburn or acid reflux
# - Loss of appetite
# - Change in bowel habits (diarrhea or constipation)
# The specific signs and severity of stomach ache can vary depending on the underlying cause. It is always recommended to consult with a healthcare professional for appropriate treatment or if there is significant discomfort, particularly when other serious health concerns should be considered like gallstones or kidney stones

# %%
print(llm("what is sign of headache"))
# Out:
# The symptoms of a migraine usually appear between 10 to 60 minutes after the onset of the headache. Some people may experience warning signs or an aura up to an hour before the headache starts. These can include:
# Visual disturbances, such as seeing flashes of light, zigzag patterns or blind spots.
# Aura, where vision or speech is briefly interrupted and you see a temporary loss of vision with a bright spot in your field of vision.
# Other less common signs may also indicate that a migraine is coming on, including:
# Numbness or tingling in the face or limbs.
# Weakness or clumsiness in the hands.
# Dizziness or difficulty walking.
# A feeling of unsteadiness or lightheadedness.
# If you experience any of these signs or symptoms, it’s important to take note and try to identify any triggers that may be causing your migraines. This can help you manage your condition more effectively.
